# %%
import tensorflow as tf
import numpy as np

print(tf.__version__)
print(np.__version__)
# Out:
# 2.6.0
# 1.22.2

# %% [markdown]
# ### 이미지 만들기
# 티처블머신(https://teachablemachine.withgoogle.com/)
# - 웹캠으로 이미지를 만들어서 클래스별로 저장(예. scissor.zip, paper.zip, rock.zip)
# - 클라우드에 업로드 한 후 압축을 푼다.(aiffel/scissor_rock_paper/scisscor, ...)

# %%
from PIL import Image
import glob
import os

print("PIL 라이브러리 import 완료!")
# Out:
# PIL 라이브러리 import 완료!

# %% [markdown]
# ### 그루들의 데이터를 모아서 해보려고 한다.
# - 문제 : 이미지 화일 이름이 1, 2, 3, ... 으로 만들어져 있어서 화일명이 겹침.
# - 그래서, 이미지 화일을 train폴더에 넣은 후 순회 하면서 이미지 사이즈 조절하기로 함.
# - 이미지 화일은 train/이름/paper, train/이름/scissor, train/이름/rock 밑에 넣고 압축 풀면 된다.

# %%
def resize_images(img_path):
    images=glob.glob(img_path + "/*.jpg")  
    
    #rint(len(images), " images to be resized.")
    #print(type(images[0])) #.shape)
    # 파일마다 모두 28x28 사이즈로 바꾸어 저장합니다.
    target_size=(28,28)
    for img in images:
        old_img=Image.open(img)
        new_img=old_img.resize(target_size,Image.ANTIALIAS)
        new_img.save(img, "JPEG")
    
    print(len(images), " images resized.")
    
start_dir_list = ["~/aiffel/rock_scissor_paper", 
                  "~/aiffel/rock_scissor_paper_hh_je/test"]
for strat_dir in start_dir_list:
    start_dir = os.path.expanduser(start_dir)

    for subdir, _, _ in os.walk(start_dir):
        image_dir_path =  os.path.abspath(subdir)
        print(image_dir_path)
        resize_images(image_dir_path)

print("이미지 resize 완료!")
# Out:
# /aiffel/aiffel/rock_scissor_paper
# 0  images resized.
# /aiffel/aiffel/rock_scissor_paper/scissor
# 0  images resized.
# /aiffel/aiffel/rock_scissor_paper/test
# 0  images resized.
# /aiffel/aiffel/rock_scissor_paper/test/scissor
# 115  images resized.
# /aiffel/aiffel/rock_scissor_paper/test/rock
# 124  images resized.
# /aiffel/aiffel/rock_scissor_paper/test/paper
# 114  images resized.
# /aiffel/aiffel/rock_scissor_paper/test/yeonji
# 0  images resized.
# /aiffel/aiffel/rock_scissor_paper/test/yeonji/scissor
# 117  images resized.
# /aiffel/aiffel/rock_scissor_paper/test/yeonji/rock
# 122  images resized.
# /aiffel/aiffel/rock_scissor_paper/test/yeonji/paper
# 111  images resized.
# /aiffel/aiffel/rock_scissor_paper/rock
# 0  images resized.
# /aiffel/aiffel/rock_scissor_paper/paper
# 0  images resized.
# /aiffel/aiffel/rock_scissor_paper/rock_scissor_paper_hh_je
# 0  images resized.
# /aiffel/aiffel/rock_scissor_paper/rock_scissor_paper_hh_je/scissor
# 598  images resized.
# /aiffel/aiffel/rock_scissor_paper/rock_scissor_paper_hh_je/test
# 0  images resized.
# /aiffel/aiffel/rock_scissor_paper/rock_scissor_paper_hh_je/test/scissor
# 445  images resized.
# /aiffel/aiffel/rock_scissor_paper/rock_scissor_paper_hh_je/test/rock
# 545  images resized.
# /aiffel/aiffel/rock_scissor_paper/rock_scissor_paper_hh_je/test/paper
# 449  images resized.
# /aiffel/aiffel/rock_scissor_paper/rock_scissor_paper_hh_je/rock
# 535  images resized.
# /aiffel/aiffel/rock_scissor_paper/rock_scissor_paper_hh_je/paper
# 511  images resized.
# 이미지 resize 완료!

# %% [markdown]
# ### 데이터 로드
# - 가위: 0, 바위: 1, 보:2로 라벨링 됨.
# - 최대 500개까지 받고 들어오는 숫자에 맞춰서 데이터 사이즈를 조절하게 코드 변경

# %%
import numpy as np
import os

def load_data(img_path, max_number_of_data=10000):  # 가위바위보 이미지 개수 총합에 주의하세요.
    # 가위 : 0, 바위 : 1, 보 : 2
    img_size=28
    color=3
    #이미지 데이터와 라벨(가위 : 0, 바위 : 1, 보 : 2) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
    imgs=np.zeros(max_number_of_data*img_size*img_size*color,dtype=np.int32).reshape(max_number_of_data,img_size,img_size,color)
    labels=np.zeros(max_number_of_data,dtype=np.int32)

    idx=0
    for file in glob.iglob(img_path+'/scissor/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=0   # 가위 : 0
        idx=idx+1

    for file in glob.iglob(img_path+'/rock/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=1   # 바위 : 1
        idx=idx+1  
    
    for file in glob.iglob(img_path+'/paper/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=2   # 보 : 2
        idx=idx+1
        
    print("데이터의 이미지 개수는", idx,"입니다.")
    imgs = imgs[:idx]
    labels = labels[:idx]

    return imgs, labels

image_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper_hh_je"
print(image_path)

(x_data, y_data)=load_data(image_path)

x_data = x_data/255.0   # 입력은 0~1 사이의 값으로 정규화

# print("x_data shape: {}".format(x_train.shape))
# print("y_train shape: {}".format(y_train.shape))
# Out:
# /aiffel/aiffel/rock_scissor_paper_hh_je
# 데이터의 이미지 개수는 1644 입니다.

# %%
print(x_data.shape)
print(y_data.shape)
# Out:
# (1644, 28, 28, 3)
# (1644,)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers

import numpy as np

# model을 직접 만들어 보세요.
# Hint! model의 입력/출력부에 특히 유의해 주세요. 가위바위보 데이터셋은 MNIST 데이터셋과 어떤 점이 달라졌나요?
n_channel_1=16
n_channel_2=48
n_channel_3=64
n_dense_1= 128
n_dense_2 = 64
n_train_epoch=20

model=keras.models.Sequential()
model.add(keras.layers.Conv2D(n_channel_1, (3,3), \
                              activation='relu', \
                              input_shape=(28,28,3)))
model.add(keras.layers.MaxPool2D(2,2))
model.add(keras.layers.Conv2D(n_channel_2, (3,3), activation='relu'))
model.add(keras.layers.MaxPooling2D((2,2)))
model.add(keras.layers.Conv2D(n_channel_3, (3,3), activation='relu'))
model.add(keras.layers.MaxPooling2D((2,2)))
#model.add(keras.layers.Conv2D(n_channel_3, (3,3), activation='relu'))
#model.add(keras.layers.MaxPooling2D((2,2)))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(n_dense_1, activation='relu'))
#model.add(keras.layers.BatchNormalization())  # Batch Normalization
model.add(keras.layers.Dense(n_dense_2, activation='relu'))
#model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(3, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_36"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_109 (Conv2D)          (None, 26, 26, 16)        448
# _________________________________________________________________
# max_pooling2d_105 (MaxPoolin (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_110 (Conv2D)          (None, 11, 11, 48)        6960
# _________________________________________________________________
# max_pooling2d_106 (MaxPoolin (None, 5, 5, 48)          0
# _________________________________________________________________
# conv2d_111 (Conv2D)          (None, 3, 3, 64)          27712
# _________________________________________________________________
# max_pooling2d_107 (MaxPoolin (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 64)                0
# _________________________________________________________________
# dense_92 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dense_93 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_94 (Dense)             (None, 3)                 195
# =================================================================
# Total params: 51,891
# Trainable params: 51,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
# model을 학습시키는 코드를 직접 작성해 보세요.
# Hint! model.compile()과 model.fit()을 사용해 봅시다.
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# 훈련 데이터의 비율
train_ratio = 0.8
train_size = int(x_data.shape[0] * train_ratio)


# 임의의 인덱스 선택
train_indices = np.random.choice(x_data.shape[0], train_size, replace=False)
eval_indices = np.setdiff1d(np.arange(x_data.shape[0]), train_indices)

# 데이터 분할
x_train = x_data[train_indices]
y_train = y_data[train_indices]
x_eval = x_data[eval_indices]
y_eval = y_data[eval_indices]

print(f"Training data shape: {x_train.shape}")
print(f"Evaluation data shape: {x_eval.shape}")

# 3. 훈련 및 평가
history = model.fit(x_train, y_train, epochs=n_train_epoch, batch_size=32, validation_data=(x_eval, y_eval))

# 4. 결과를 그래프로 표시
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy over epochs')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss over epochs')

plt.tight_layout()
plt.show()
# Out:
# Training data shape: (1315, 28, 28, 3)
# Evaluation data shape: (329, 28, 28, 3)
# Epoch 1/20
# 42/42 [==============================] - 2s 29ms/step - loss: 1.0198 - accuracy: 0.4639 - val_loss: 0.7334 - val_accuracy: 0.6839
# Epoch 2/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.5008 - accuracy: 0.7970 - val_loss: 0.4142 - val_accuracy: 0.7751
# Epoch 3/20
# 42/42 [==============================] - 1s 27ms/step - loss: 0.2441 - accuracy: 0.9103 - val_loss: 0.2425 - val_accuracy: 0.9027
# Epoch 4/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.1703 - accuracy: 0.9384 - val_loss: 0.1400 - val_accuracy: 0.9422
# Epoch 5/20
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0882 - accuracy: 0.9741 - val_loss: 0.0704 - val_accuracy: 0.9878
# Epoch 6/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0516 - accuracy: 0.9901 - val_loss: 0.0440 - val_accuracy: 0.9939
# Epoch 7/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0433 - accuracy: 0.9878 - val_loss: 0.0527 - val_accuracy: 0.9848
# Epoch 8/20
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0403 - accuracy: 0.9901 - val_loss: 0.0576 - val_accuracy: 0.9757
# Epoch 9/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0200 - accuracy: 0.9970 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 10/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0138 - accuracy: 0.9985 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 11/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0075 - accuracy: 0.9992 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 12/20
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0063 - accuracy: 0.9992 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 13/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 14/20
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 15/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 16/20
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 17/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 18/20
# 42/42 [==============================] - 1s 26ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 19/20
# 42/42 [==============================] - 1s 26ms/step - loss: 9.9136e-04 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 20/20
# 42/42 [==============================] - 1s 26ms/step - loss: 8.5191e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000

# %%
for idx in np.random.choice(x_train.shape[0], 10):
    #idx=150 #1번째 x_test를 살펴보자. 
    print('실제 데이터의 라벨 : ', y_train[idx])

    plt.imshow(x_train[idx])
    plt.show()
# Out:
# 실제 데이터의 라벨 :  1
# 실제 데이터의 라벨 :  1
# 실제 데이터의 라벨 :  2
# 실제 데이터의 라벨 :  0
# 실제 데이터의 라벨 :  1
# 실제 데이터의 라벨 :  0
# 실제 데이터의 라벨 :  2
# 실제 데이터의 라벨 :  0
# 실제 데이터의 라벨 :  1
# 실제 데이터의 라벨 :  1

# %%
predicted_result = model.predict(x_train)  # model이 추론한 확률값. 
predicted_labels = np.argmax(predicted_result, axis=1)

for idx in np.random.choice(x_train.shape[0], 10):
    #idx=150 #1번째 x_test를 살펴보자. 
    print('model.predict() 결과 : ', predicted_result[idx])
    print('model이 추론한 가장 가능성이 높은 결과 : ', predicted_labels[idx])
    print('실제 데이터의 라벨 : ', y_train[idx])

    plt.imshow(x_train[idx])
    plt.show()
# Out:
# model.predict() 결과 :  [9.4227465e-03 9.9054563e-01 3.1587748e-05]
# model이 추론한 가장 가능성이 높은 결과 :  1
# 실제 데이터의 라벨 :  1
# model.predict() 결과 :  [1.8093714e-11 1.0000000e+00 1.3188106e-10]
# model이 추론한 가장 가능성이 높은 결과 :  1
# 실제 데이터의 라벨 :  1
# model.predict() 결과 :  [9.9993098e-01 4.2680764e-05 2.6376432e-05]
# model이 추론한 가장 가능성이 높은 결과 :  0
# 실제 데이터의 라벨 :  0
# model.predict() 결과 :  [9.9993682e-01 5.3089276e-05 1.0120261e-05]
# model이 추론한 가장 가능성이 높은 결과 :  0
# 실제 데이터의 라벨 :  0
# model.predict() 결과 :  [7.6067378e-03 9.9237728e-01 1.5980653e-05]
# model이 추론한 가장 가능성이 높은 결과 :  1
# 실제 데이터의 라벨 :  1
# model.predict() 결과 :  [0.00443916 0.00703896 0.98852193]
# model이 추론한 가장 가능성이 높은 결과 :  2
# 실제 데이터의 라벨 :  2
# model.predict() 결과 :  [2.4896592e-03 8.2979379e-05 9.9742728e-01]
# model이 추론한 가장 가능성이 높은 결과 :  2
# 실제 데이터의 라벨 :  2
# model.predict() 결과 :  [1.0987715e-03 1.5653311e-05 9.9888557e-01]
# model이 추론한 가장 가능성이 높은 결과 :  2
# 실제 데이터의 라벨 :  2
# model.predict() 결과 :  [9.7705346e-01 1.0265360e-08 2.2946550e-02]
# model이 추론한 가장 가능성이 높은 결과 :  0
# 실제 데이터의 라벨 :  0
# model.predict() 결과 :  [9.9998617e-01 1.3596301e-05 2.0818264e-07]
# model이 추론한 가장 가능성이 높은 결과 :  0
# 실제 데이터의 라벨 :  0

# %%
predicted_result = model.predict(x_test_norm)  # model이 추론한 확률값. 
predicted_labels = np.argmax(predicted_result, axis=1)

for idx in np.random.choice(len(predicted_labels), 10):
    #idx=150 #1번째 x_test를 살펴보자. 
    print('model.predict() 결과 : ', predicted_result[idx])
    print('model이 추론한 가장 가능성이 높은 결과 : ', predicted_labels[idx])
    print('실제 데이터의 라벨 : ', y_test[idx])

    plt.imshow(x_test[idx])
    plt.show()
# Out:
# model.predict() 결과 :  [1.2210219e-07 9.9999607e-01 3.8580552e-06]
# model이 추론한 가장 가능성이 높은 결과 :  1
# 실제 데이터의 라벨 :  1
# model.predict() 결과 :  [0.6170389  0.00172262 0.3812385 ]
# model이 추론한 가장 가능성이 높은 결과 :  0
# 실제 데이터의 라벨 :  0
# model.predict() 결과 :  [0.39124852 0.0009742  0.60777724]
# model이 추론한 가장 가능성이 높은 결과 :  2
# 실제 데이터의 라벨 :  0
# model.predict() 결과 :  [0.03072528 0.01209065 0.9571841 ]
# model이 추론한 가장 가능성이 높은 결과 :  2
# 실제 데이터의 라벨 :  1
# model.predict() 결과 :  [0.6721826  0.00087701 0.3269404 ]
# model이 추론한 가장 가능성이 높은 결과 :  0
# 실제 데이터의 라벨 :  1
# model.predict() 결과 :  [8.6043205e-04 1.6312179e-03 9.9750829e-01]
# model이 추론한 가장 가능성이 높은 결과 :  2
# 실제 데이터의 라벨 :  2
# model.predict() 결과 :  [0.9651519  0.00191406 0.032934  ]
# model이 추론한 가장 가능성이 높은 결과 :  0
# 실제 데이터의 라벨 :  1
# model.predict() 결과 :  [0.15811601 0.00621949 0.83566445]
# model이 추론한 가장 가능성이 높은 결과 :  2
# 실제 데이터의 라벨 :  0
# model.predict() 결과 :  [0.741939   0.17149505 0.08656595]
# model이 추론한 가장 가능성이 높은 결과 :  0
# 실제 데이터의 라벨 :  2
# model.predict() 결과 :  [0.0166744  0.00966589 0.9736597 ]
# model이 추론한 가장 가능성이 높은 결과 :  2
# 실제 데이터의 라벨 :  2

# %%
import matplotlib.pyplot as plt

#test_image_path = "/aiffel/rock_scissor_paper_hh_je/test"
test_image_path = "/aiffel/rock_scissor_paper/test/yeonji"
test_image_path = "/aiffel/rock_scissor_paper_org/test"


# 바위 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
image_dir_path = os.getenv("HOME") + test_image_path + "/scissor"
resize_images(image_dir_path)
image_dir_path = os.getenv("HOME") + test_image_path + "/rock"
resize_images(image_dir_path)
image_dir_path = os.getenv("HOME") + test_image_path + "/paper"
resize_images(image_dir_path)

image_dir_path = os.getenv("HOME") + test_image_path
(x_test, y_test)=load_data(image_dir_path)

x_test_norm = x_test/255.0

plt.imshow(x_test[10])
plt.show()

print(x_test_norm.shape)
print(y_test.shape)
# Out:
# 100  images resized.
# 100  images resized.
# 100  images resized.
# 데이터의 이미지 개수는 300 입니다.
# (300, 28, 28, 3)
# (300,)

# %%
idx = 0
plt.imshow(x_test_norm[idx])
print(y_test[idx])
# Out:
# 0

# %%
# model을 학습시키는 코드를 직접 작성해 보세요.
# Hint! model.evaluate()을 사용해 봅시다.
test_loss, test_accuracy = model.evaluate(x_test_norm, y_test, verbose=2)
print(f"test_loss: {test_loss} ")
print(f"test_accuracy: {test_accuracy}")
# Out:
# 10/10 - 0s - loss: 3.8608 - accuracy: 0.4067
# test_loss: 3.860778331756592
# test_accuracy: 0.40666666626930237

# %%
idx = 500
plt.imshow(x_train[idx],cmap=plt.cm.binary)
plt.show()
print(y_train[idx])
# Out:
# 0

# %%
from PIL import Image
import numpy as np

def save_numpy_images_as_files(numpy_images, base_filename):
    for idx in range(numpy_images.shape[0]):
        image_data = numpy_images[idx]
        
        # NumPy 배열의 데이터 타입을 uint8로 변환합니다. (0~255의 정수 값)
        img_data_uint8 = (image_data * 255).astype(np.uint8)
        
        # NumPy 배열을 PIL 이미지로 변환합니다.
        img = Image.fromarray(img_data_uint8)
        
        # 파일명에 인덱스를 포함하여 이미지를 파일로 저장합니다.
        img.save(f"{base_filename}_{idx}.jpg")

# 선택한 레이블에 따라 이미지를 필터링하고 파일로 저장합니다.
selected_images = x_train[y_train[:, 0] == 0]  # 주의: y_train의 형태에 따라 인덱싱을 조정해야 할 수 있습니다.
save_numpy_images_as_files(selected_images, './scissor/img')

# 선택한 레이블에 따라 이미지를 필터링하고 파일로 저장합니다.
selected_images = x_train[y_train[:, 0] == 1]  # 주의: y_train의 형태에 따라 인덱싱을 조정해야 할 수 있습니다.
save_numpy_images_as_files(selected_images, './rock/img')

# 선택한 레이블에 따라 이미지를 필터링하고 파일로 저장합니다.
selected_images = x_train[y_train[:, 0] == 2]  # 주의: y_train의 형태에 따라 인덱싱을 조정해야 할 수 있습니다.
save_numpy_images_as_files(selected_images, './paper/img')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_31/1872691618.py in <module>
#      16
#      17 # 선택한 레이블에 따라 이미지를 필터링하고 파일로 저장합니다.
# ---> 18 selected_images = x_train[y_train[:, 0] == 0]  # 주의: y_train의 형태에 따라 인덱싱을 조정해야 할 수 있습니다.
#      19 save_numpy_images_as_files(selected_images, './scissor/img')
#      20
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
os.getcwd()
# Out:
# '/aiffel/aiffel/AIFFEL_Quest/AIFFEL_Quest/ML_Quest/MainQuest03'

# %%
from PIL import Image
import os

def rotate_and_save_images(folder_path):
    # 폴더 내의 모든 파일에 대해
    for filename in os.listdir(folder_path):
        # 이미지 파일만 대상으로
        if filename.endswith('.jpg') or filename.endswith('.png'):  # 다른 확장자도 추가 가능
            image_path = os.path.join(folder_path, filename)
            img = Image.open(image_path)

            # 90도, 180도, 270도 회전하고 저장
            for angle in [-15, 15, 30, 45]:
                rotated_img = img.rotate(angle)
                new_filename = f"{filename.split('.')[0]}_{angle}.jpg"  # 원본 파일 이름에 각도를 추가
                rotated_img.save(os.path.join(folder_path, new_filename))

# 폴더 경로 지정
#folder_path = '/aiffel/rock_scissor_paper/rock'
rotate_and_save_images('/aiffel/aiffel/rock_scissor_paper/rock')
rotate_and_save_images('/aiffel/aiffel/rock_scissor_paper/paper')
rotate_and_save_images('/aiffel/aiffel/rock_scissor_paper/scissor')
